# %%
# %load_ext autoreload
# %autoreload 1

# %%
# %aimport utils

# %%
from utils import load_experiment_results, list_filepaths

# %%
EXPERIMENTS_ROOT_PATH = '/mnt/workspace/Behance/ExperimentResults/'

# %%
experiment_files = list_filepaths(EXPERIMENTS_ROOT_PATH)

# %%
df_results = load_experiment_results(experiment_files)

# %%
df_results.sort_values('AUC', ascending=False)
# Out:
#                               NAME       AUC
# 7                         FA(p+np)  0.852611
# 6                             npFA  0.766478
# 17                             MPI  0.760425
# 0       VGG19-PCA500-cosine-avgsim  0.661279
# 15      VGG19-PCA400-cosine-avgsim  0.661226
# 13      VGG19-PCA300-cosine-avgsim  0.661181
# 28      VGG19-PCA200-cosine-avgsim  0.661048
# 26      VGG19-PCA100-cosine-avgsim  0.660360
# 23  VGG19-PCA300-cosine-avgsimtop3  0.653270
# 22  VGG19-PCA200-cosine-avgsimtop3  0.653240
# 10  VGG19-PCA400-cosine-avgsimtop3  0.653135
# 27  VGG19-PCA500-cosine-avgsimtop3  0.653103
# 19                             pFA  0.653082
# 11  VGG19-PCA100-cosine-avgsimtop3  0.652803
# 9   VGG19-PCA200-cosine-avgsimtop2  0.649391
# 8   VGG19-PCA300-cosine-avgsimtop2  0.649326
# 29  VGG19-PCA400-cosine-avgsimtop2  0.649200
# 16  VGG19-PCA100-cosine-avgsimtop2  0.649111
# 12  VGG19-PCA500-cosine-avgsimtop2  0.649068
# 2       VGG19-PCA300-cosine-maxsim  0.640667
# ...
